# %% [markdown]
# <a href="https://colab.research.google.com/github/gimb99/PDH_INTEGRADOR_GRUPAL_X/blob/main/paso_1_definir_caso_de_uso_y_corpus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🎯 Objetivo general del sistema
#
# El presente sistema RAG (Retrieval-Augmented Generation) tiene como objetivo principal facilitar el acceso a información técnica y académica sobre reservorios de hidrocarburos no convencionales a estudiantes de Ingeniería e ingenieros en formación o sin experiencia directa en operaciones de campo.
#
# A través de una interfaz intuitiva desarrollada en Streamlit, el usuario podrá realizar preguntas en lenguaje natural relacionadas con yacimientos no convencionales, fracturamiento hidráulico, estimulación, ingeniería de reservorios, producción y perforación, y obtener respuestas generadas por un modelo de lenguaje preentrenado de Hugging Face, enriquecidas con contexto extraído dinámicamente desde un corpus documental vectorizado.

# %% [markdown]
# 📂 Sobre el corpus
#
# El corpus ha sido conformado por documentos técnicos, manuales, papers y presentaciones en PDF relacionados con:
#
# Técnicas de fracturamiento hidráulico
#
# Producción en shale/tight formations
#
# Parámetros de diseño y operación de pozos
#
# Simulación de reservorios
#
# Casos reales (e.g., Barnett Shale, Vaca Muerta)
#
# Estos documentos han sido extraídos mayoritariamente de fuentes académicas o industriales (e.g., YPF, Tecpetrol), y serán transformados en vectores semánticos mediante embeddings obtenidos con modelos de sentence-transformers (Hugging Face), para ser indexados en ChromaDB, una base vectorial local.

# %% [markdown]
# 🧱 Stack tecnológico utilizado
# | Componente                     | Tecnología elegida                                     |
# |-------------------------------|--------------------------------------------------------|
# | LLM para generación           | Modelos preentrenados de Hugging Face (`flan-t5`, `mistral`, etc.) |
# | Embeddings                    | `sentence-transformers` (ej. `all-MiniLM-L6-v2`)      |
# | Vector Store                  | `ChromaDB`                                             |
# | Framework de orquestación     | `LangChain`                                            |
# | Interfaz                      | `Streamlit`                                            |
# | Despliegue                    | `Hugging Face Spaces`                                  |

# %% [markdown]
# 🧠 Tareas que realiza el sistema
#
# ✅ Carga automática de documentos PDF técnicos
#
# ✅ División inteligente del contenido en fragmentos con LangChain
#
# ✅ Vectorización semántica con sentence-transformers
#
# ✅ Almacenamiento en ChromaDB
#
# ✅ Recuperación de fragmentos más relevantes en base a una pregunta del usuario
#
# ✅ Generación de respuesta por parte de un modelo de lenguaje de Hugging Face
#
# ✅ Visualización de respuesta + fuente del fragmento en Streamlit

# %% [markdown]
# 💡 ¿Qué problema específico resuelve este sistema?
#
# Los estudiantes de Ingeniería y profesionales en formación sin experiencia en campo suelen tener dificultades para acceder de forma rápida, precisa y contextualizada a información técnica real sobre reservorios de hidrocarburos no convencionales.
#
# La mayoría de los documentos relevantes están en formatos PDF extensos, difíciles de navegar y con lenguaje técnico complejo. Esto dificulta el aprendizaje y la consulta puntual de temas como fracturamiento hidráulico, presión de poro, permeabilidad, diseño de pozos horizontales, etc.

# %% [markdown]
# 🚀 ¿Por qué un sistema RAG es mejor para este caso?
#
# A diferencia de las búsquedas tradicionales o lecturas manuales, un sistema RAG:
#
# ✅ Comprende el lenguaje técnico del área (vocabulario específico del upstream petrolero)
#
# ✅ Extrae fragmentos relevantes del corpus técnico a partir de una pregunta en lenguaje natural
#
# ✅ Presenta respuestas sintetizadas por un LLM, ahorrando tiempo y mejorando la comprensión
#
# ✅ Muestra la fuente exacta del documento, permitiendo profundizar si se desea
#
# ✅ Reduce el esfuerzo cognitivo de buscar entre cientos de páginas en múltiples documentos
#
# ✅ Se puede usar desde cualquier dispositivo con interfaz simple (Streamlit en Hugging Face Spaces)

# %% [markdown]
# 🧠 Justificación técnica-pedagógica
#
# El sistema RAG se convierte en una herramienta educativa con valor técnico real, ya que combina:
#
# Recuperación de documentos precisos
#
# Interpretación asistida por modelos de lenguaje
#
# Transparencia de fuentes
#
# Accesibilidad para perfiles no expertos
#
# Esto aporta autonomía al estudiante y fomenta un aprendizaje más activo, técnico y situado en escenarios reales del campo energético.

# %% [markdown]
# ### ❌ ¿Qué alternativas existen actualmente?
#
# | Alternativa actual        | Descripción                                                                 |
# |---------------------------|-----------------------------------------------------------------------------|
# | 🔍 Búsqueda manual        | Revisar documentos uno por uno, con lectura completa o uso de `Ctrl+F`.     |
# | 📚 Apuntes académicos     | Información limitada, muchas veces desactualizada o resumida en exceso.     |
# | 🧑‍🏫 Preguntar a docentes | No siempre disponible, y depende del conocimiento específico del docente.    |
# | ❌ Ninguna solución real  | En muchos casos, no existe una herramienta técnica personalizada para esta temática específica. |
